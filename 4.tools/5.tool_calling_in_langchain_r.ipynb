# %%
import os
os.environ["GROQ_API_KEY"] = "API_KEY_VALUE"

# %%
# !pip install -q langchain-groq langchain-core requests
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 2.2 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
# tool create

@tool
def multiply(a: int, b: int) -> int:
  """Given 2 numbers a and b this tool returns their product"""
  return a * b

# %%
print(multiply.invoke({'a':3, 'b':4}))
# Out:
# 12

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2 numbers a and b this tool returns their product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
# tool binding

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
llm.invoke('hi')
# Out:
# AIMessage(content="How's it going? Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 36, 'total_tokens': 58, 'completion_time': 0.032637653, 'completion_tokens_details': None, 'prompt_time': 0.006720235, 'prompt_tokens_details': None, 'queue_time': 0.072474957, 'total_time': 0.039357888}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6c980774ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019bace2-8a16-7520-aa5a-305414898681-0', usage_metadata={'input_tokens': 36, 'output_tokens': 22, 'total_tokens': 58})

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
llm_with_tools.invoke('can you multiply 3 with 1000')
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '0fpzkrac4', 'function': {'arguments': '{"a":3,"b":1000}', 'name': 'multiply'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 239, 'total_tokens': 259, 'completion_time': 0.033145237, 'completion_tokens_details': None, 'prompt_time': 0.01502989, 'prompt_tokens_details': None, 'queue_time': 0.005254839, 'total_time': 0.048175127}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019bace7-abab-7c32-8677-845770f5c73c-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 1000}, 'id': '0fpzkrac4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 239, 'output_tokens': 20, 'total_tokens': 259})

# %%
query = HumanMessage('can you multiply 3 with 1000')

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke(messages)

# %%
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6t9t5x9th', 'function': {'arguments': '{"a":3,"b":1000}', 'name': 'multiply'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 239, 'total_tokens': 259, 'completion_time': 0.036878389, 'completion_tokens_details': None, 'prompt_time': 0.021352637, 'prompt_tokens_details': None, 'queue_time': 0.073257235, 'total_time': 0.058231026}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9ca2574dca', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019bace3-3299-7d20-b5ec-771826301602-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 1000}, 'id': '6t9t5x9th', 'type': 'tool_call'}], usage_metadata={'input_tokens': 239, 'output_tokens': 20, 'total_tokens': 259})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
tool_result
# Out:
# ToolMessage(content='3000', name='multiply', tool_call_id='6t9t5x9th')

# %%
messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '6t9t5x9th', 'function': {'arguments': '{"a":3,"b":1000}', 'name': 'multiply'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 239, 'total_tokens': 259, 'completion_time': 0.036878389, 'completion_tokens_details': None, 'prompt_time': 0.021352637, 'prompt_tokens_details': None, 'queue_time': 0.073257235, 'total_time': 0.058231026}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9ca2574dca', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019bace3-3299-7d20-b5ec-771826301602-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 1000}, 'id': '6t9t5x9th', 'type': 'tool_call'}], usage_metadata={'input_tokens': 239, 'output_tokens': 20, 'total_tokens': 259}),
#  ToolMessage(content='3000', name='multiply', tool_call_id='6t9t5x9th')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The product of 3 and 1000 is 3000.'

# %%
# tool create
from langchain_core.tools import InjectedToolArg
from typing import Annotated

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
  """
  This function fetches the currency conversion factor between a given base currency and a target currency
  """
  url = f'https://v6.exchangerate-api.com/v6/c754eab14ffab33112e380ca/pair/{base_currency}/{target_currency}'

  response = requests.get(url)

  return response.json()

@tool
def convert(base_currency_value: int, conversion_rate: Annotated[float, InjectedToolArg]) -> float:
  """
  given a currency conversion rate this function calculates the target currency value from a given base currency value
  """

  return base_currency_value * conversion_rate

# %%
convert.args
# Out:
# {'base_currency_value': {'title': 'Base Currency Value', 'type': 'integer'},
#  'conversion_rate': {'title': 'Conversion Rate', 'type': 'number'}}

# %%
get_conversion_factor.invoke({'base_currency':'USD','target_currency':'INR'})
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1768089601,
#  'time_last_update_utc': 'Sun, 11 Jan 2026 00:00:01 +0000',
#  'time_next_update_unix': 1768176001,
#  'time_next_update_utc': 'Mon, 12 Jan 2026 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'INR',
#  'conversion_rate': 90.1802}

# %%
convert.invoke({'base_currency_value':10, 'conversion_rate':85.16})
# Out:
# 851.5999999999999

# %%
# tool binding
llm = llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
llm_with_tools = llm.bind_tools([get_conversion_factor, convert])

# %%
messages = [HumanMessage('What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd')]

# %%
messages
# Out:
# [HumanMessage(content='What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd', additional_kwargs={}, response_metadata={})]

# %%
ai_message = llm_with_tools.invoke(messages)

# %%
messages.append(ai_message)

# %%
ai_message.tool_calls
# Out:
# [{'name': 'get_conversion_factor',
#   'args': {'base_currency': 'INR', 'target_currency': 'USD'},
#   'id': 'xd9whsz9x',
#   'type': 'tool_call'},
#  {'name': 'convert',
#   'args': {'base_currency_value': 10, 'conversion_factor': 0.014},
#   'id': 'v87qtmd2j',
#   'type': 'tool_call'}]

# %%
import json

for tool_call in ai_message.tool_calls:
  # execute the 1st tool and get the value of conversion rate
  if tool_call['name'] == 'get_conversion_factor':
    tool_message1 = get_conversion_factor.invoke(tool_call)
    # fetch this conversion rate
    conversion_rate = json.loads(tool_message1.content)['conversion_rate']
    # append this tool message to messages list
    messages.append(tool_message1)
  # execute the 2nd tool using the conversion rate from tool 1
  if tool_call['name'] == 'convert':
    # fetch the current arg
    tool_call['args']['conversion_rate'] = conversion_rate
    tool_message2 = convert.invoke(tool_call)
    messages.append(tool_message2)

# %%
messages
# Out:
# [HumanMessage(content='What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'xd9whsz9x', 'function': {'arguments': '{"base_currency":"INR","target_currency":"USD"}', 'name': 'get_conversion_factor'}, 'type': 'function'}, {'id': 'v87qtmd2j', 'function': {'arguments': '{"base_currency_value":10,"conversion_factor":0.014}', 'name': 'convert'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 350, 'total_tokens': 397, 'completion_time': 0.074949677, 'completion_tokens_details': None, 'prompt_time': 0.029156755, 'prompt_tokens_details': None, 'queue_time': 0.02078808, 'total_time': 0.104106432}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6b5c123dd9', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019bad5c-4403-7442-bcaa-2bf7ce0f2982-0', tool_calls=[{'name': 'get_conversion_factor', 'args': {'base_currency': 'INR', 'target_currency': 'USD'}, 'id': 'xd9whsz9x', 'type': 'tool_call'}, {'name': 'convert', 'args': {'base_currency_value': 10, 'conversion_factor': 0.014, 'conversion_rate': 0.01109}, 'id': 'v87qtmd2j', 'type': 'tool_call'}], usage_metadata={'input_tokens': 350, 'output_tokens': 47, 'total_tokens': 397}),
#  ToolMessage(content='{"result": "success", "documentation": "https://www.exchangerate-api.com/docs", "terms_of_use": "https://www.exchangerate-api.com/terms", "time_last_update_unix": 1768089601, "time_last_update_utc": "Sun, 11 Jan 2026 00:00:01 +0000", "time_next_update_unix": 1768176001, "time_next_update_utc": "Mon, 12 Jan 2026 00:00:01 +0000", "base_code": "INR", "target_code": "USD", "conversion_rate": 0.01109}', name='get_conversion_factor', tool_call_id='xd9whsz9x'),
#  ToolMessage(content='0.1109', name='convert', tool_call_id='v87qtmd2j')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The conversion factor between INR and USD is 1 INR = 0.01109 USD. So, 10 INR is equivalent to 0.1109 USD.'
